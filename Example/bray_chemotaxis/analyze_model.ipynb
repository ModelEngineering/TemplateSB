# %% [markdown]
# # Analysis of Models to Templatize

# %%
# %matplotlib inline
import tellurium as te
import matplotlib.pyplot as plt
# Out:
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/tellurium/notebooks/__init__.py:16: UserWarning: Notebook tools are not imported, due to missing dependencies.
#   warnings.warn("Notebook tools are not imported, due to missing dependencies.")

# %%
def getAntimonyModel(biomodel):
  """
  :param str biomodel: string identifier of the biomodel
  """
  url = "http://www.ebi.ac.uk/biomodels-main/download?mid=%s" % biomodel
  return te.loadSBMLModel(url).getAntimony()

# %%
fd = open("BIOMD0000000200.mdl", "w")
fd.writelines(getAntimonyModel("BIOMD0000000200"))
fd.close()

# %%
print("{s} => {s}p")
# Out:
# {s} => {s}p

# %%
a = '''
TTWWAA => TTWWAAp
AA => AAp
WAA => WAAp
WWAA => WWAAp
TTAA => TTAAp
TTWAA => TTWAAp
Y => Yp
'''
print(a)
# Out:
# TTWWAA => TTWWAAp
# AA => AAp
# WAA => WAAp
# WWAA => WWAAp
# TTAA => TTAAp
# TTWAA => TTWAAp
# Y => Yp

# %%
print("{s}p{n} => {s}p{n+1}")
# Out:
# {s}p{n} => {s}p{n+1}

# %%
#print getAntimonyModel("BIOMD0000000223")

# %%
#print getAntimonyModel("BIOMD0000000090")

# %%
#print getAntimonyModel("insulin_model.xml")

# %%
#antimonyStr = te.loadSBMLModel("insulin_model.xml").getAntimony()
#print(antimonyStr)

# %%
model = getAntimonyModel("BIOMD0000000090")
rr = te.loada(model)
result = rr.simulate(0, 1800, 1000)
#// Outputs
#plot "EGF/Insulin Crosstalk, nM (y) vs sec (x) (Borsiov, 2009)" time vs tRas, ppErk +
#pErk, ppAkt + pAkt
# rr.plot(['tRas'], loc=None, show=True,
#           linewidth=2.0, linestyle='-', color='black', alpha=0.8).show()
phrasedmlStr = '''
model = model "Wolf2001_Respiratory_Oscillations"
// Simulation
simulation1 = simulate uniform_stochastic(0, 2000, 10)
// Tasks
task = run simulation1 on model

// Plots
plot "ATM Model: Protein Numbers" task.time vs task.SHP2
'''

phrasedmlStr = \
'''
model1 =  model "Wolf2001_Respiratory_Oscillations"
// Simulations
sim1 = simulate uniform(0, 100, 1000)
// Tasks
task1 = run sim1 on model1
// Outputs
plot "Limit cycle oscillations (Wolf, 2001)" time vs A3m, A3c, N2, oxy, hyd

plot "Phase plot" oxy vs A3m, A3c, N2, hyd
'''

exp = te.experiment(model, phrasedmlStr)
exp.execute()
# Out:
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/tellurium/sedml/tephrasedml.py:247: UserWarning: No phrasedml string selected, defaulting to first phrasedml.
#   warnings.warn("No phrasedml string selected, defaulting to first phrasedml.")

# %%
tab = '''
Re(pat='CT', pfx='complex',  num=1,   m1='TT',     m2='W'                )
Re(                          num=2,   m1='W',      m2='AA'               )
Re(                          num=3,   m1='TT',     m2='WAA'              )
Re(                          num=4,   m1='TTW',    m2='WAA'              )
Re(                          num=5,   m1='TTWW',   m2='AA'               )
Re(                          num=6,   m1='TT',     m2='WWAA'             )
Re(                          num=7,   m1='TT',     m2='AA'               )
Re(                          num=8,   m1='TTW',    m2='AA'               )
Re(                          num=10,  m1='TTWW',   m2='W'                )
Re(                          num=11,  m1='W',      m2='WAA'              )
Re(                          num=9,   m1='TTWAA',  m2='W',   mf='TTWWAA' )
Re(                          num=12,  m1='W',      m2='W',   mf='TTWAA'  )
'''
print(tab)
# Out:
# Re(pat='CT', pfx='complex',  num=1,   m1='TT',     m2='W'                )
# Re(                          num=2,   m1='W',      m2='AA'               )
# Re(                          num=3,   m1='TT',     m2='WAA'              )
# Re(                          num=4,   m1='TTW',    m2='WAA'              )
# Re(                          num=5,   m1='TTWW',   m2='AA'               )
# Re(                          num=6,   m1='TT',     m2='WWAA'             )
# Re(                          num=7,   m1='TT',     m2='AA'               )
# Re(                          num=8,   m1='TTW',    m2='AA'               )
# Re(                          num=10,  m1='TTWW',   m2='W'                )
# Re(                          num=11,  m1='W',      m2='WAA'              )
# Re(                          num=9,   m1='TTWAA',  m2='W',   mf='TTWWAA' )
# Re(                          num=12,  m1='W',      m2='W',   mf='TTWAA'  )

# %%
mdl = '''
complex_r1: TTW -> TT + W; cell*(complex_r1_k1*TTW - complex_r1_k2*TT*W);
complex_r2: WAA -> W + AA; cell*(complex_r2_k1*WAA - complex_r2_k2*W*AA);
complex_r3: TTWAA -> TT + WAA; cell*(complex_r3_k1*TTWAA - complex_r3_k2*TT*WAA);
complex_r4: TTWWAA -> TTW + WAA; cell*(complex_r4_k1*TTWWAA - complex_r4_k2*TTW*WAA);
complex_r5: TTWWAA -> TTWW + AA; cell*(complex_r5_k1*TTWWAA - complex_r5_k2*TTWW*AA);
complex_r6: TTWWAA -> TT + WWAA; cell*(complex_r6_k1*TTWWAA - complex_r6_k2*TT*WWAA);
complex_r7: TTAA -> TT + AA; cell*(complex_r7_k1*TTAA - complex_r7_k2*TT*AA);
complex_r8: TTWAA -> TTW + AA; cell*(complex_r8_k1*TTWAA - complex_r8_k2*TTW*AA);
complex_r9: TTWWAA -> TTWAA + W; cell*(complex_r9_k1*TTWWAA - complex_r9_k2*TTWAA*W);
complex_r10: TTWW -> TTW + W; cell*(complex_r10_k1*TTWW - complex_r10_k2*TTW*W);
complex_r11: WWAA -> W + WAA; cell*(complex_r11_k1*WWAA - complex_r11_k2*W*WAA);
complex_r12: TTWAA -> TTAA + W; cell*(complex_r12_k1*TTWAA - complex_r12_k2*TTAA*W);
'''
print(mdl)
# Out:
# complex_r1: TTW -> TT + W; cell*(complex_r1_k1*TTW - complex_r1_k2*TT*W);
# complex_r2: WAA -> W + AA; cell*(complex_r2_k1*WAA - complex_r2_k2*W*AA);
# complex_r3: TTWAA -> TT + WAA; cell*(complex_r3_k1*TTWAA - complex_r3_k2*TT*WAA);
# complex_r4: TTWWAA -> TTW + WAA; cell*(complex_r4_k1*TTWWAA - complex_r4_k2*TTW*WAA);
# complex_r5: TTWWAA -> TTWW + AA; cell*(complex_r5_k1*TTWWAA - complex_r5_k2*TTWW*AA);
# complex_r6: TTWWAA -> TT + WWAA; cell*(complex_r6_k1*TTWWAA - complex_r6_k2*TT*WWAA);
# complex_r7: TTAA -> TT + AA; cell*(complex_r7_k1*TTAA - complex_r7_k2*TT*AA);
# complex_r8: TTWAA -> TTW + AA; cell*(complex_r8_k1*TTWAA - complex_r8_k2*TTW*AA);
# complex_r9: TTWWAA -> TTWAA + W; cell*(complex_r9_k1*TTWWAA - complex_r9_k2*TTWAA*W);
# complex_r10: TTWW -> TTW + W; cell*(complex_r10_k1*TTWW - complex_r10_k2*TTW*W);
# complex_r11: WWAA -> W + WAA; cell*(complex_r11_k1*WWAA - complex_r11_k2*W*WAA);
# complex_r12: TTWAA -> TTAA + W; cell*(complex_r12_k1*TTWAA - complex_r12_k2*TTAA*W);

# %%
constants = '''
complex_r1_k1 = 0.00365;
  complex_r1_k1 has persec;
  complex_r1_k2 = 1000000;
  complex_r1_k2 has perMpersec;
  complex_r2_k1 = 0.00894;
  complex_r2_k1 has persec;
  complex_r2_k2 = 1000000;
  complex_r2_k2 has perMpersec;
  complex_r3_k1 = 297;
  complex_r3_k1 has persec;
  complex_r3_k2 = 1000000;
  complex_r3_k2 has perMpersec;
  complex_r4_k1 = 0.64;
  complex_r4_k1 has persec;
  complex_r4_k2 = 1000000;
  complex_r4_k2 has perMpersec;
  complex_r5_k1 = 0.112;
  complex_r5_k1 has persec;
  complex_r5_k2 = 1000000;
  complex_r5_k2 has perMpersec;
  complex_r6_k1 = 0.0229;
  complex_r6_k1 has persec;
  complex_r6_k2 = 1000000;
  complex_r6_k2 has perMpersec;
  complex_r7_k1 = 39.3;
  complex_r7_k1 has persec;
  complex_r7_k2 = 1000000;
  complex_r7_k2 has perMpersec;
  complex_r8_k1 = 727;
  complex_r8_k1 has persec;
  complex_r8_k2 = 1000000;
  complex_r8_k2 has perMpersec;
  complex_r9_k1 = 7.87e-06;
  complex_r9_k1 has persec;
  complex_r9_k2 = 1000000;
  complex_r9_k2 has perMpersec;
  complex_r10_k1 = 0.0511;
  complex_r10_k1 has persec;
  complex_r10_k2 = 1000000;
  complex_r10_k2 has perMpersec;
  complex_r11_k1 = 0.102;
  complex_r11_k1 has persec;
  complex_r11_k2 = 1000000;
  complex_r11_k2 has perMpersec;
  complex_r12_k1 = 0.0676;
  complex_r12_k1 has persec;
  complex_r12_k2 = 1000000;
  complex_r12_k2 has perMpersec;
'''
print(constants.replace('  complex', 'complex'))
# Out:
# complex_r1_k1 = 0.00365;
# complex_r1_k1 has persec;
# complex_r1_k2 = 1000000;
# complex_r1_k2 has perMpersec;
# complex_r2_k1 = 0.00894;
# complex_r2_k1 has persec;
# complex_r2_k2 = 1000000;
# complex_r2_k2 has perMpersec;
# complex_r3_k1 = 297;
# complex_r3_k1 has persec;
# complex_r3_k2 = 1000000;
# complex_r3_k2 has perMpersec;
# complex_r4_k1 = 0.64;
# complex_r4_k1 has persec;
# complex_r4_k2 = 1000000;
# complex_r4_k2 has perMpersec;
# complex_r5_k1 = 0.112;
# complex_r5_k1 has persec;
# complex_r5_k2 = 1000000;
# complex_r5_k2 has perMpersec;
# complex_r6_k1 = 0.0229;
# complex_r6_k1 has persec;
# complex_r6_k2 = 1000000;
# complex_r6_k2 has perMpersec;
# complex_r7_k1 = 39.3;
# complex_r7_k1 has persec;
# complex_r7_k2 = 1000000;
# complex_r7_k2 has perMpersec;
# complex_r8_k1 = 727;
# complex_r8_k1 has persec;
# complex_r8_k2 = 1000000;
# complex_r8_k2 has perMpersec;
# complex_r9_k1 = 7.87e-06;
# complex_r9_k1 has persec;
# complex_r9_k2 = 1000000;
# complex_r9_k2 has perMpersec;
# complex_r10_k1 = 0.0511;
# complex_r10_k1 has persec;
# complex_r10_k2 = 1000000;
# complex_r10_k2 has perMpersec;
# complex_r11_k1 = 0.102;
# complex_r11_k1 has persec;
# complex_r11_k2 = 1000000;
# complex_r11_k2 has perMpersec;
# complex_r12_k1 = 0.0676;
# complex_r12_k1 has persec;
# complex_r12_k2 = 1000000;
# complex_r12_k2 has perMpersec;

# %%
table = '''
Co(pfx='complex', num=1,  k1v=0.00365, k1u='persec', k2v=1000000, k2u='perMpersec')
Co(               num=2,  k1v=0.00894                                             )
Co(               num=3,  k1v=297                                                 )
Co(               num=4,  k1v=0.64                                                )
Co(               num=5,  k1v=0.112                                               )
Co(               num=6,  k1v=0.022                                               )
Co(               num=7,  k1v=39.3                                                )
Co(               num=8,  k1v=727                                                 )
Co(               num=9,  k1v=7.87e-06                                            )
Co(               num=10, k1v=0.102                                               )
Co(               num=12, k1v=0.0676                                              )
'''
print(table)
# Out:
# Co(pfx='complex', num=1,  k1v=0.00365, k1u='persec', k2v=1000000, k2u='perMpersec')
# Co(               num=2,  k1v=0.00894                                             )
# Co(               num=3,  k1v=297                                                 )
# Co(               num=4,  k1v=0.64                                                )
# Co(               num=5,  k1v=0.112                                               )
# Co(               num=6,  k1v=0.022                                               )
# Co(               num=7,  k1v=39.3                                                )
# Co(               num=8,  k1v=727                                                 )
# Co(               num=9,  k1v=7.87e-06                                            )
# Co(               num=10, k1v=0.102                                               )
# Co(               num=12, k1v=0.0676                                              )

# %%
biomodel = "BIOMD0000000640"
print getAntimonyModel(biomodel)
# Out:
# // Created by libAntimony v2.8.1
# function function_6(IRS_p, IRS_p_phos_by_p70_S6K_pT229_pT389, p70_S6K_pT229_pT389)
#   IRS_p_phos_by_p70_S6K_pT229_pT389*IRS_p*p70_S6K_pT229_pT389;
# end
#
# function function_3(Amino_Acids, mTORC2, mTORC2_S2481_phos_by_Amino_Acids)
#   mTORC2_S2481_phos_by_Amino_Acids*mTORC2*Amino_Acids;
# end
#
# function function_14(Akt_S473_phos_by_mTORC2_pS2481_second, Akt_pT308, mTORC2_pS2481)
#   Akt_S473_phos_by_mTORC2_pS2481_second*Akt_pT308*mTORC2_pS2481;
# end
#
# function function_17(TSC1_TSC2, TSC1_TSC2_pS1387, mTORC1_pS2448, mTORC1_pS2448_dephos_by_TSC1_TSC2)
#   mTORC1_pS2448_dephos_by_TSC1_TSC2*mTORC1_pS2448*(TSC1_TSC2 + TSC1_TSC2_pS1387);
# end
#
# function function_20(PI3K_p_PDK1, p70_S6K, p70_S6K_T229_phos_by_PI3K_p_PDK1_first)
#   p70_S6K_T229_phos_by_PI3K_p_PDK1_first*p70_S6K*PI3K_p_PDK1;
# end
#
# function function_19(PI3K_variant_p, mTORC2, mTORC2_S2481_phos_by_PI3K_variant_p)
#   mTORC2_S2481_phos_by_PI3K_variant_p*mTORC2*PI3K_variant_p;
# end
#
# function function_2(AMPK, AMPK_T172_phos_by_Amino_Acids, Amino_Acids)
#   AMPK_T172_phos_by_Amino_Acids*AMPK*Amino_Acids;
# end
#
# function function_4(IR_beta, IR_beta_phos_by_Insulin, Insulin)
#   IR_beta_phos_by_Insulin*IR_beta*Insulin;
# end
#
# function function_23(mTORC1_pS2448, p70_S6K_T389_phos_by_mTORC1_pS2448_second, p70_S6K_pT229)
#   p70_S6K_T389_phos_by_mTORC1_pS2448_second*p70_S6K_pT229*mTORC1_pS2448;
# end
#
# function function_22(PI3K_p_PDK1, p70_S6K_T229_phos_by_PI3K_p_PDK1_second, p70_S6K_pT389)
#   p70_S6K_T229_phos_by_PI3K_p_PDK1_second*p70_S6K_pT389*PI3K_p_PDK1;
# end
#
# function function_16(Akt_pT308, Akt_pT308_pS473, TSC1_TSC2, TSC1_TSC2_T1462_phos_by_Akt_pT308)
#   TSC1_TSC2_T1462_phos_by_Akt_pT308*TSC1_TSC2*(Akt_pT308 + Akt_pT308_pS473);
# end
#
# function function_11(Akt, Akt_T308_phos_by_PI3K_p_PDK1_first, PI3K_p_PDK1)
#   Akt_T308_phos_by_PI3K_p_PDK1_first*Akt*PI3K_p_PDK1;
# end
#
# function function_27(PRAS40_S183_phos_by_mTORC1_pS2448_second, PRAS40_pT246, mTORC1_pS2448)
#   PRAS40_S183_phos_by_mTORC1_pS2448_second*PRAS40_pT246*mTORC1_pS2448;
# end
#
# function function_26(Akt_pT308, Akt_pT308_pS473, PRAS40_T246_phos_by_Akt_pT308_second, PRAS40_pS183)
#   PRAS40_T246_phos_by_Akt_pT308_second*PRAS40_pS183*(Akt_pT308 + Akt_pT308_pS473);
# end
#
# function function_7(IRS, IRS_phos_by_p70_S6K_pT229_pT389, p70_S6K_pT229_pT389)
#   IRS_phos_by_p70_S6K_pT229_pT389*IRS*p70_S6K_pT229_pT389;
# end
#
# function function_15(AMPK_pT172, TSC1_TSC2, TSC1_TSC2_S1387_phos_by_AMPK_pT172)
#   TSC1_TSC2_S1387_phos_by_AMPK_pT172*TSC1_TSC2*AMPK_pT172;
# end
#
# function function_9(IR_beta_pY1146, PI3K_variant, PI3K_variant_phos_by_IR_beta_pY1146)
#   PI3K_variant_phos_by_IR_beta_pY1146*PI3K_variant*IR_beta_pY1146;
# end
#
# function function_12(Akt, Akt_S473_phos_by_mTORC2_pS2481_first, mTORC2_pS2481)
#   Akt_S473_phos_by_mTORC2_pS2481_first*Akt*mTORC2_pS2481;
# end
#
# function function_18(Amino_Acids, mTORC1, mTORC1_S2448_activation_by_Amino_Acids)
#   mTORC1_S2448_activation_by_Amino_Acids*mTORC1*Amino_Acids;
# end
#
# function function_10(AMPK, AMPK_T172_phos, IRS_p)
#   AMPK_T172_phos*AMPK*IRS_p;
# end
#
# function function_13(Akt_T308_phos_by_PI3K_p_PDK1_second, Akt_pS473, PI3K_p_PDK1)
#   Akt_T308_phos_by_PI3K_p_PDK1_second*Akt_pS473*PI3K_p_PDK1;
# end
#
# function function_8(IRS_p, PI3K_PDK1, PI3K_PDK1_phos_by_IRS_p)
#   PI3K_PDK1_phos_by_IRS_p*PI3K_PDK1*IRS_p;
# end
#
# function function_21(mTORC1_pS2448, p70_S6K, p70_S6K_T389_phos_by_mTORC1_pS2448_first)
#   p70_S6K_T389_phos_by_mTORC1_pS2448_first*p70_S6K*mTORC1_pS2448;
# end
#
# function function_5(IRS, IRS_phos_by_IR_beta_pY1146, IR_beta_pY1146)
#   IRS_phos_by_IR_beta_pY1146*IRS*IR_beta_pY1146;
# end
#
# function function_24(PRAS40, PRAS40_S183_phos_by_mTORC1_pS2448_first, mTORC1_pS2448)
#   PRAS40_S183_phos_by_mTORC1_pS2448_first*PRAS40*mTORC1_pS2448;
# end
#
# function function_25(Akt_pT308, Akt_pT308_pS473, PRAS40, PRAS40_T246_phos_by_Akt_pT308_first)
#   PRAS40_T246_phos_by_Akt_pT308_first*PRAS40*(Akt_pT308 + Akt_pT308_pS473);
# end
#
# function function_1(Amino_Acids, IRS, IRS_phos_by_Amino_Acids)
#   IRS_phos_by_Amino_Acids*IRS*Amino_Acids;
# end
#
#
# model *MODEL1702270000()
#
#   // Compartments and Species:
#   compartment Cell;
#   species IR_beta in Cell, IR_beta_pY1146 in Cell, IR_beta_refractory in Cell;
#   species IRS in Cell, IRS_p in Cell, IRS_pS636 in Cell, AMPK in Cell, AMPK_pT172 in Cell;
#   species Akt in Cell, Akt_pT308 in Cell, Akt_pS473 in Cell, Akt_pT308_pS473 in Cell;
#   species TSC1_TSC2 in Cell, TSC1_TSC2_pT1462 in Cell, TSC1_TSC2_pS1387 in Cell;
#   species mTORC1 in Cell, mTORC1_pS2448 in Cell, mTORC2 in Cell, mTORC2_pS2481 in Cell;
#   species p70_S6K in Cell, p70_S6K_pT229 in Cell, p70_S6K_pT389 in Cell, p70_S6K_pT229_pT389 in Cell;
#   species PRAS40 in Cell, PRAS40_pT246 in Cell, PRAS40_pS183 in Cell, PRAS40_pT246_pS183 in Cell;
#   species PI3K_variant in Cell, PI3K_variant_p in Cell, PI3K_PDK1 in Cell;
#   species PI3K_p_PDK1 in Cell, $Insulin in Cell, $Amino_Acids in Cell, $IR_beta_pY1146_obs in Cell;
#   species $IRS_pS636_obs in Cell, $AMPK_pT172_obs in Cell, $Akt_pT308_obs in Cell;
#   species $Akt_pS473_obs in Cell, $TSC1_TSC2_pS1387_obs in Cell, $mTOR_pS2448_obs in Cell;
#   species $mTOR_pS2481_obs in Cell, $p70_S6K_pT229_obs in Cell, $p70_S6K_pT389_obs in Cell;
#   species $PRAS40_pT246_obs in Cell, $PRAS40_pS183_obs in Cell;
#
#   // Assignment Rules:
#   Insulin := piecewise(0, time < 0, 0);
#   Amino_Acids := piecewise(0, time < 0, 1);
#   IR_beta_pY1146_obs := IR_beta_pY1146;
#   IRS_pS636_obs := IRS_pS636;
#   AMPK_pT172_obs := AMPK_pT172;
#   Akt_pT308_obs := Akt_pT308 + Akt_pT308_pS473;
#   Akt_pS473_obs := Akt_pS473 + Akt_pT308_pS473;
#   TSC1_TSC2_pS1387_obs := TSC1_TSC2_pS1387;
#   mTOR_pS2448_obs := mTORC1_pS2448;
#   mTOR_pS2481_obs := mTORC2_pS2481;
#   p70_S6K_pT229_obs := p70_S6K_pT229 + p70_S6K_pT229_pT389;
#   p70_S6K_pT389_obs := p70_S6K_pT389 + p70_S6K_pT229_pT389;
#   PRAS40_pT246_obs := PRAS40_pT246 + PRAS40_pT246_pS183;
#   PRAS40_pS183_obs := PRAS40_pS183 + PRAS40_pT246_pS183;
#
#   // Reactions:
#   reaction_1: IRS => IRS_p; Cell*function_1(Amino_Acids, IRS, IRS_phos_by_Amino_Acids);
#   reaction_2: AMPK => AMPK_pT172; Cell*function_2(AMPK, AMPK_T172_phos_by_Amino_Acids, Amino_Acids);
#   reaction_3: mTORC2 => mTORC2_pS2481; Cell*function_3(Amino_Acids, mTORC2, mTORC2_S2481_phos_by_Amino_Acids);
#   reaction_4: IR_beta => IR_beta_pY1146; Cell*function_4(IR_beta, IR_beta_phos_by_Insulin, Insulin);
#   reaction_5: IR_beta_pY1146 => IR_beta_refractory; Cell*IR_beta_pY1146_dephos*IR_beta_pY1146;
#   reaction_6: IR_beta_refractory => IR_beta; Cell*IR_beta_ready*IR_beta_refractory;
#   reaction_7: IRS => IRS_p; Cell*function_5(IRS, IRS_phos_by_IR_beta_pY1146, IR_beta_pY1146);
#   reaction_8: IRS_p => IRS_pS636; Cell*function_6(IRS_p, IRS_p_phos_by_p70_S6K_pT229_pT389, p70_S6K_pT229_pT389);
#   reaction_9: IRS => IRS_pS636; Cell*function_7(IRS, IRS_phos_by_p70_S6K_pT229_pT389, p70_S6K_pT229_pT389);
#   reaction_10: IRS_pS636 => IRS; Cell*IRS_pS636_turnover*IRS_pS636;
#   reaction_11: PI3K_p_PDK1 => PI3K_PDK1; Cell*PI3K_p_PDK1_dephos*PI3K_p_PDK1;
#   reaction_12: PI3K_PDK1 => PI3K_p_PDK1; Cell*function_8(IRS_p, PI3K_PDK1, PI3K_PDK1_phos_by_IRS_p);
#   reaction_13: PI3K_variant_p => PI3K_variant; Cell*PI3K_variant_p_dephos*PI3K_variant_p;
#   reaction_14: PI3K_variant => PI3K_variant_p; Cell*function_9(IR_beta_pY1146, PI3K_variant, PI3K_variant_phos_by_IR_beta_pY1146);
#   reaction_15: AMPK => AMPK_pT172; Cell*function_10(AMPK, AMPK_T172_phos, IRS_p);
#   reaction_16: AMPK_pT172 => AMPK; Cell*AMPK_pT172_dephos*AMPK_pT172;
#   reaction_17: Akt => Akt_pT308; Cell*function_11(Akt, Akt_T308_phos_by_PI3K_p_PDK1_first, PI3K_p_PDK1);
#   reaction_18: Akt => Akt_pS473; Cell*function_12(Akt, Akt_S473_phos_by_mTORC2_pS2481_first, mTORC2_pS2481);
#   reaction_19: Akt_pS473 => Akt_pT308_pS473; Cell*function_13(Akt_T308_phos_by_PI3K_p_PDK1_second, Akt_pS473, PI3K_p_PDK1);
#   reaction_20: Akt_pT308 => Akt_pT308_pS473; Cell*function_14(Akt_S473_phos_by_mTORC2_pS2481_second, Akt_pT308, mTORC2_pS2481);
#   reaction_21: Akt_pT308 => Akt; Cell*Akt_pT308_dephos_first*Akt_pT308;
#   reaction_22: Akt_pS473 => Akt; Cell*Akt_pS473_dephos_first*Akt_pS473;
#   reaction_23: Akt_pT308_pS473 => Akt_pS473; Cell*Akt_pT308_dephos_second*Akt_pT308_pS473;
#   reaction_24: Akt_pT308_pS473 => Akt_pT308; Cell*Akt_pS473_dephos_second*Akt_pT308_pS473;
#   reaction_25: TSC1_TSC2 => TSC1_TSC2_pS1387; Cell*function_15(AMPK_pT172, TSC1_TSC2, TSC1_TSC2_S1387_phos_by_AMPK_pT172);
#   reaction_26: TSC1_TSC2 => TSC1_TSC2_pT1462; Cell*function_16(Akt_pT308, Akt_pT308_pS473, TSC1_TSC2, TSC1_TSC2_T1462_phos_by_Akt_pT308);
#   reaction_27: TSC1_TSC2_pS1387 => TSC1_TSC2; Cell*TSC1_TSC2_pS1387_dephos*TSC1_TSC2_pS1387;
#   reaction_28: TSC1_TSC2_pT1462 => TSC1_TSC2; Cell*TSC1_TSC2_pT1462_dephos*TSC1_TSC2_pT1462;
#   reaction_29: mTORC1_pS2448 => mTORC1; Cell*function_17(TSC1_TSC2, TSC1_TSC2_pS1387, mTORC1_pS2448, mTORC1_pS2448_dephos_by_TSC1_TSC2);
#   reaction_30: mTORC1 => mTORC1_pS2448; Cell*function_18(Amino_Acids, mTORC1, mTORC1_S2448_activation_by_Amino_Acids);
#   reaction_31: mTORC2 => mTORC2_pS2481; Cell*function_19(PI3K_variant_p, mTORC2, mTORC2_S2481_phos_by_PI3K_variant_p);
#   reaction_32: mTORC2_pS2481 => mTORC2; Cell*mTORC2_pS2481_dephos*mTORC2_pS2481;
#   reaction_33: p70_S6K => p70_S6K_pT229; Cell*function_20(PI3K_p_PDK1, p70_S6K, p70_S6K_T229_phos_by_PI3K_p_PDK1_first);
#   reaction_34: p70_S6K => p70_S6K_pT389; Cell*function_21(mTORC1_pS2448, p70_S6K, p70_S6K_T389_phos_by_mTORC1_pS2448_first);
#   reaction_35: p70_S6K_pT389 => p70_S6K_pT229_pT389; Cell*function_22(PI3K_p_PDK1, p70_S6K_T229_phos_by_PI3K_p_PDK1_second, p70_S6K_pT389);
#   reaction_36: p70_S6K_pT229 => p70_S6K_pT229_pT389; Cell*function_23(mTORC1_pS2448, p70_S6K_T389_phos_by_mTORC1_pS2448_second, p70_S6K_pT229);
#   reaction_37: p70_S6K_pT229 => p70_S6K; Cell*p70_S6K_pT229_dephos_first*p70_S6K_pT229;
#   reaction_38: p70_S6K_pT389 => p70_S6K; Cell*p70_S6K_pT389_dephos_first*p70_S6K_pT389;
#   reaction_39: p70_S6K_pT229_pT389 => p70_S6K_pT389; Cell*p70_S6K_pT229_dephos_second*p70_S6K_pT229_pT389;
#   reaction_40: p70_S6K_pT229_pT389 => p70_S6K_pT229; Cell*p70_S6K_pT389_dephos_second*p70_S6K_pT229_pT389;
#   reaction_41: PRAS40 => PRAS40_pS183; Cell*function_24(PRAS40, PRAS40_S183_phos_by_mTORC1_pS2448_first, mTORC1_pS2448);
#   reaction_42: PRAS40 => PRAS40_pT246; Cell*function_25(Akt_pT308, Akt_pT308_pS473, PRAS40, PRAS40_T246_phos_by_Akt_pT308_first);
#   reaction_43: PRAS40_pS183 => PRAS40_pT246_pS183; Cell*function_26(Akt_pT308, Akt_pT308_pS473, PRAS40_T246_phos_by_Akt_pT308_second, PRAS40_pS183);
#   reaction_44: PRAS40_pT246 => PRAS40_pT246_pS183; Cell*function_27(PRAS40_S183_phos_by_mTORC1_pS2448_second, PRAS40_pT246, mTORC1_pS2448);
#   reaction_45: PRAS40_pS183 => PRAS40; Cell*PRAS40_pS183_dephos_first*PRAS40_pS183;
#   reaction_46: PRAS40_pT246 => PRAS40; Cell*PRAS40_pT246_dephos_first*PRAS40_pT246;
#   reaction_47: PRAS40_pT246_pS183 => PRAS40_pT246; Cell*PRAS40_pS183_dephos_second*PRAS40_pT246_pS183;
#   reaction_48: PRAS40_pT246_pS183 => PRAS40_pS183; Cell*PRAS40_pT246_dephos_second*PRAS40_pT246_pS183;
#
#   // Species initializations:
#   IR_beta = 50;
#   IR_beta_pY1146 = 0;
#   IR_beta_refractory = 0;
#   IRS = 150;
#   IRS_p = 0;
#   IRS_pS636 = 0;
#   AMPK = 50;
#   AMPK_pT172 = 0;
#   Akt = 300;
#   Akt_pT308 = 0;
#   Akt_pS473 = 0;
#   Akt_pT308_pS473 = 0;
#   TSC1_TSC2 = 50;
#   TSC1_TSC2_pT1462 = 0;
#   TSC1_TSC2_pS1387 = 0;
#   mTORC1 = 100;
#   mTORC1_pS2448 = 0;
#   mTORC2 = 100;
#   mTORC2_pS2481 = 0;
#   p70_S6K = 300;
#   p70_S6K_pT229 = 0;
#   p70_S6K_pT389 = 0;
#   p70_S6K_pT229_pT389 = 0;
#   PRAS40 = 20;
#   PRAS40_pT246 = 0;
#   PRAS40_pS183 = 0;
#   PRAS40_pT246_pS183 = 0;
#   PI3K_variant = 50;
#   PI3K_variant_p = 0;
#   PI3K_PDK1 = 50;
#   PI3K_p_PDK1 = 0;
#
#   // Compartment initializations:
#   Cell = 1;
#
#   // Variable initializations:
#   IRS_phos_by_Amino_Acids = 0.0331672;
#   AMPK_T172_phos_by_Amino_Acids = 17.6284;
#   mTORC2_S2481_phos_by_Amino_Acids = 0.0268658;
#   IR_beta_phos_by_Insulin = 0.0203796;
#   IR_beta_pY1146_dephos = 0.493514;
#   IR_beta_ready = 323.611;
#   IRS_phos_by_IR_beta_pY1146 = 2.11894;
#   IRS_p_phos_by_p70_S6K_pT229_pT389 = 0.338859859949792;
#   IRS_phos_by_p70_S6K_pT229_pT389 = 0.0863775267376444;
#   IRS_pS636_turnover = 25;
#   AMPK_T172_phos = 0.490602;
#   AMPK_pT172_dephos = 165.704;
#   Akt_S473_phos_by_mTORC2_pS2481_first = 1.31992e-05;
#   Akt_S473_phos_by_mTORC2_pS2481_second = 0.159093;
#   Akt_T308_phos_by_PI3K_p_PDK1_first = 7.47437;
#   Akt_T308_phos_by_PI3K_p_PDK1_second = 7.47345;
#   Akt_pT308_dephos_first = 88.9654;
#   Akt_pT308_dephos_second = 88.9639;
#   Akt_pS473_dephos_first = 0.376999;
#   Akt_pS473_dephos_second = 0.380005;
#   TSC1_TSC2_S1387_phos_by_AMPK_pT172 = 0.00175772;
#   TSC1_TSC2_T1462_phos_by_Akt_pT308 = 1.52417;
#   TSC1_TSC2_pS1387_dephos = 0.25319;
#   TSC1_TSC2_pT1462_dephos = 147.239;
#   mTORC1_pS2448_dephos_by_TSC1_TSC2 = 0.00869774;
#   mTORC1_S2448_activation_by_Amino_Acids = 0.0156992;
#   mTORC2_pS2481_dephos = 1.42511;
#   mTORC2_S2481_phos_by_PI3K_variant_p = 0.120736;
#   p70_S6K_T229_phos_by_PI3K_p_PDK1_first = 0.0133520172873009;
#   p70_S6K_T229_phos_by_PI3K_p_PDK1_second = 1.00000002814509e-06;
#   p70_S6K_T389_phos_by_mTORC1_pS2448_first = 0.00261303413778722;
#   p70_S6K_T389_phos_by_mTORC1_pS2448_second = 0.110720890919343;
#   p70_S6K_pT229_dephos_first = 1.00000012897033e-06;
#   p70_S6K_pT229_dephos_second = 0.159201353240651;
#   p70_S6K_pT389_dephos_first = 1.10036057608758;
#   p70_S6K_pT389_dephos_second = 1.10215267954479;
#   PRAS40_S183_phos_by_mTORC1_pS2448_first = 0.15881;
#   PRAS40_S183_phos_by_mTORC1_pS2448_second = 0.0683009;
#   PRAS40_T246_phos_by_Akt_pT308_first = 0.279344;
#   PRAS40_T246_phos_by_Akt_pT308_second = 0.279401;
#   PRAS40_pS183_dephos_first = 1.8706;
#   PRAS40_pS183_dephos_second = 1.88453;
#   PRAS40_pT246_dephos_first = 11.8759;
#   PRAS40_pT246_dephos_second = 11.876;
#   PI3K_p_PDK1_dephos = 0.18913343080532;
#   PI3K_PDK1_phos_by_IRS_p = 0.000187226757782201;
#   PI3K_variant_p_dephos = 0.108074886441184;
#   PI3K_variant_phos_by_IR_beta_pY1146 = 0.000549027801822575;
#   scale_IR_beta_pY1146_obs = 1;
#   scale_IRS_pS636_obs = 1;
#   scale_AMPK_pT172_obs = 1;
#   scale_Akt_pT308_obs = 1;
#   scale_Akt_pS473_obs = 1;
#   scale_TSC1_TSC2_pS1387_obs = 1;
#   scale_mTOR_pS2448_obs = 1;
#   scale_mTOR_pS2481_obs = 1;
#   scale_p70_S6K_pT229_obs = 1;
#   scale_p70_S6K_pT389_obs = 1;
#   scale_PRAS40_pT246_obs = 1;
#   scale_PRAS40_pS183_obs = 1;
#
#   // Other declarations:
#   const Cell, IRS_phos_by_Amino_Acids, AMPK_T172_phos_by_Amino_Acids, mTORC2_S2481_phos_by_Amino_Acids;
#   const IR_beta_phos_by_Insulin, IR_beta_pY1146_dephos, IR_beta_ready, IRS_phos_by_IR_beta_pY1146;
#   const IRS_p_phos_by_p70_S6K_pT229_pT389, IRS_phos_by_p70_S6K_pT229_pT389;
#   const IRS_pS636_turnover, AMPK_T172_phos, AMPK_pT172_dephos, Akt_S473_phos_by_mTORC2_pS2481_first;
#   const Akt_S473_phos_by_mTORC2_pS2481_second, Akt_T308_phos_by_PI3K_p_PDK1_first;
#   const Akt_T308_phos_by_PI3K_p_PDK1_second, Akt_pT308_dephos_first, Akt_pT308_dephos_second;
#   const Akt_pS473_dephos_first, Akt_pS473_dephos_second, TSC1_TSC2_S1387_phos_by_AMPK_pT172;
#   const TSC1_TSC2_T1462_phos_by_Akt_pT308, TSC1_TSC2_pS1387_dephos, TSC1_TSC2_pT1462_dephos;
#   const mTORC1_pS2448_dephos_by_TSC1_TSC2, mTORC1_S2448_activation_by_Amino_Acids;
#   const mTORC2_pS2481_dephos, mTORC2_S2481_phos_by_PI3K_variant_p, p70_S6K_T229_phos_by_PI3K_p_PDK1_first;
#   const p70_S6K_T229_phos_by_PI3K_p_PDK1_second, p70_S6K_T389_phos_by_mTORC1_pS2448_first;
#   const p70_S6K_T389_phos_by_mTORC1_pS2448_second, p70_S6K_pT229_dephos_first;
#   const p70_S6K_pT229_dephos_second, p70_S6K_pT389_dephos_first, p70_S6K_pT389_dephos_second;
#   const PRAS40_S183_phos_by_mTORC1_pS2448_first, PRAS40_S183_phos_by_mTORC1_pS2448_second;
#   const PRAS40_T246_phos_by_Akt_pT308_first, PRAS40_T246_phos_by_Akt_pT308_second;
#   const PRAS40_pS183_dephos_first, PRAS40_pS183_dephos_second, PRAS40_pT246_dephos_first;
#   const PRAS40_pT246_dephos_second, PI3K_p_PDK1_dephos, PI3K_PDK1_phos_by_IRS_p;
#   const PI3K_variant_p_dephos, PI3K_variant_phos_by_IR_beta_pY1146, scale_IR_beta_pY1146_obs;
#   const scale_IRS_pS636_obs, scale_AMPK_pT172_obs, scale_Akt_pT308_obs, scale_Akt_pS473_obs;
#   const scale_TSC1_TSC2_pS1387_obs, scale_mTOR_pS2448_obs, scale_mTOR_pS2481_obs;
#   const scale_p70_S6K_pT229_obs, scale_p70_S6K_pT389_obs, scale_PRAS40_pT246_obs;
#   const scale_PRAS40_pS183_obs;
#
#   // Unit definitions:
#   unit volume = dimensionless;
#   unit time_unit = 60 second;
#   unit substance = dimensionless;
#
#   // Display Names:
#   time_unit is "time";
# end

# %%
biomodel = "BIOMD0000000588"
#   species $mw4478fbeb_51b1_4764_92ad_a86d314ae0eb in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mw29fa4e00_a430_4f11_b62e_1bcbc0a767a0 in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mwa81400ac_76f5_4446_8a4d_6446ab4b11c9 in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mw6782adfa_29ee_41a8_acbb_4c86c6c81596 in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mwe599c4c1_2d8e_446c_bf3f_4c97baced8a9 in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mw46e8693e_348e_4f1d_8c49_c13485fae7ba in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mwe0b9d340_24f5_4c7e_a80f_4faadae6c0fc in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mw89ebbe2d_1ec2_457a_9367_6c5e86a1a924 in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#   species mw555a08dc_922d_4b35_8f69_5c6e8a4ad614 in mwc2fe3668_8fb0_4cfb_b795_99057e61e290;
#
#   // Reactions:
#   R1: $mwf82ad06a_b8aa_40fa_a532_a1da44e3425f -> NGFR + $mwf82ad06a_b8aa_40fa_a532_a1da44e3425f; kf_1*mwf82ad06a_b8aa_40fa_a532_a1da44e3425f - kb_1*NGFR;
#   R3: L_NGFR => pTrkA; kf_3*L_NGFR;
#   R4: pTrkA => pTrkA_endo; kf_4*pTrkA;
#   R5: Shc_pTrkA => Shc_pTrkA_endo; kf_5*Shc_pTrkA;
#   R6: pShc_pTrkA => pShc_pTrkA_endo; kf_6*pShc_pTrkA;
#   R7: Grb2_SOS_pShc_pTrkA => Grb2_SOS_pShc_pTrkA_endo; kf_7*Grb2_SOS_pShc_pTrkA;
#   R8: FRS2_pTrkA => FRS2_pTrkA_endo; kf_8*FRS2_pTrkA;
#   R9: pFRS2_pTrkA => pFRS2_pTrkA_endo; kf_9*pFRS2_pTrkA;
#   R10: Crk_C3G_pFRS2_pTrkA => Crk_C3G_pFRS2_pTrkA_endo; kf_10*Crk_C3G_pFRS2_pTrkA;
#   R11: pTrkA_endo => ; kf_11*pTrkA_endo;
#   R12: Shc_pTrkA_endo => Shc; kf_12*Shc_pTrkA_endo;
#   R13: pShc_pTrkA_endo => pShc; kf_13*pShc_pTrkA_endo;
#   R14: Grb2_SOS_pShc_pTrkA_endo => Grb2_SOS_pShc; kf_14*Grb2_SOS_pShc_pTrkA_endo;
#   R15: FRS2_pTrkA_endo => FRS2; kf_15*FRS2_pTrkA_endo;
#   R16: pFRS2_pTrkA_endo => pFRS2; kf_16*pFRS2_pTrkA_endo;
#   R17: Crk_C3G_pFRS2_pTrkA_endo => Crk_C3G + pFRS2; kf_17*Crk_C3G_pFRS2_pTrkA_endo;
#   R18: pTrkA + Shc => Shc_pTrkA; mwdfa3719d_20cc_4f14_b45e_3f097c3aff65*Shc*pTrkA - kb_18*Shc_pTrkA;
#   R44: Dok + pFRS2_pTrkA => pDok + pFRS2_pTrkA; Vmax_44*pFRS2_pTrkA*Dok/(Km_44 + Dok);
#   R45: Dok + Crk_C3G_pFRS2_pTrkA => pDok + Crk_C3G_pFRS2_pTrkA; Vmax_45*Crk_C3G_pFRS2_pTrkA*Dok/(Km_45 + Dok);
#   R46: Grb2 + SOS => Grb2_SOS; kf_46*Grb2*SOS - kb_46*Grb2_SOS;
#   R47: Grb2 + pSOS => Grb2_pSOS; kf_47*Grb2*pSOS - kb_47*Grb2_pSOS;
#   R48: Grb2_SOS + pShc => Grb2_SOS_pShc; kf_48*Grb2_SOS*pShc - kb_48*Grb2_SOS_pShc;
#   R49: pShc_pTrkA + Grb2_SOS => Grb2_SOS_pShc_pTrkA; kf_49*Grb2_SOS*pShc_pTrkA - kb_49*Grb2_SOS_pShc_pTrkA;
#   R50: pShc_pTrkA_endo + Grb2_SOS => Grb2_SOS_pShc_pTrkA_endo; kf_50*Grb2_SOS*pShc_pTrkA_endo - kb_50*Grb2_SOS_pShc_pTrkA_endo;
#   R51: pShc => Shc; kf_51*pShc;
#   R52: Grb2_SOS_pShc => Shc + Grb2_SOS; kf_52*Grb2_SOS_pShc;
#   R53: pSOS => SOS; kf_53*pSOS;
#   R54: Grb2_pSOS => Grb2_SOS; kf_54*Grb2_pSOS;
#   R55: pDok + RasGAP => pDok_RasGAP; kf_55*pDok*RasGAP - kb_55*pDok_RasGAP;
#   R56: pDok => Dok; kf_56*pDok - kb_56*Dok;
#   R57: Ras_GTP => Ras_GDP; kf_57*Ras_GTP;
#   R58: Ras_GDP + Grb2_SOS_pShc_pTrkA => Ras_GTP + Grb2_SOS_pShc_pTrkA; Vmax_58*Grb2_SOS_pShc_pTrkA*Ras_GDP/(Km_58 + Ras_GDP);
#   R59: SOS + dppERKcyt => pSOS + dppERKcyt; Vmax_59*dppERKcyt*SOS/(Km_59 + SOS);
#   R60: Grb2_SOS_pShc + dppERKcyt => Grb2_pSOS + pShc + dppERKcyt; Vmax_60*dppERKcyt*Grb2_SOS_pShc/(Km_60 + Grb2_SOS_pShc);
#   R61: Grb2_SOS + dppERKcyt => Grb2_pSOS + dppERKcyt; Vmax_61*dppERKcyt*Grb2_SOS/(Km_61 + Grb2_SOS);
#   R62: Ras_GTP + pDok_RasGAP => Ras_GDP + pDok_RasGAP; Vmax_62*pDok_RasGAP*Ras_GTP/(Km_62 + Ras_GTP);
#   R63: B_Raf_Ras_GTP + pDok_RasGAP => Ras_GDP + B_Raf + pDok_RasGAP; Vmax_63*pDok_RasGAP*B_Raf_Ras_GTP/(Km_63 + B_Raf_Ras_GTP);
#   R64: c_Raf_Ras_GTP + pDok_RasGAP => Ras_GDP + c_Raf + pDok_RasGAP; Vmax_64*pDok_RasGAP*c_Raf_Ras_GTP/(Km_64 + c_Raf_Ras_GTP);
#   R65: Crk + C3G => Crk_C3G; kf_65*C3G*Crk - kb_65*Crk_C3G;
#   R66: pFRS2_pTrkA + Crk_C3G => Crk_C3G_pFRS2_pTrkA; kf_66*Crk_C3G*pFRS2_pTrkA - kb_66*Crk_C3G_pFRS2_pTrkA;
#   R67: pFRS2_pTrkA_endo + Crk_C3G => Crk_C3G_pFRS2_pTrkA_endo; kf_67*Crk_C3G*pFRS2_pTrkA_endo - kb_67*Crk_C3G_pFRS2_pTrkA_endo;
#   R68: pFRS2 => FRS2; kf_68*pFRS2;
#   R69: Rap1_GTP => Rap1_GDP; kf_69*Rap1_GTP;
#   R70: Rap1_GDP + Crk_C3G_pFRS2_pTrkA_endo => Rap1_GTP + Crk_C3G_pFRS2_pTrkA_endo; Vmax_70*Crk_C3G_pFRS2_pTrkA_endo*Rap1_GDP/(Km_70 + Rap1_GDP);
#   R71: Rap1_GTP => Rap1_GDP; Vmax_71*Rap1GAP*Rap1_GTP/(Km_71 + Rap1_GTP);
#   R72: B_Raf_Rap1_GTP => B_Raf + Rap1_GDP; Vmax_72*Rap1GAP*B_Raf_Rap1_GTP/(Km_72 + B_Raf_Rap1_GTP);
#   R73: Ras_GTP + c_Raf => c_Raf_Ras_GTP; kf_73*c_Raf*Ras_GTP - kb_73*c_Raf_Ras_GTP;
#   R74: Ras_GTP + B_Raf => B_Raf_Ras_GTP; kf_74*B_Raf*Ras_GTP - kb_74*B_Raf_Ras_GTP;
#   R75: B_Raf + Rap1_GTP => B_Raf_Rap1_GTP; kf_75*B_Raf*Rap1_GTP - kb_75*B_Raf_Rap1_GTP;
#   R76: ppMEKcyt_ERKcyt => ppMEKcyt + ppERKcyt; kf_76*ppMEKcyt_ERKcyt;
#   R77: 2ppERKcyt => dppERKcyt; kf_77*ppERKcyt*ppERKcyt - kb_77*dppERKcyt;
#   R78: MEKcyt + ERKcyt => MEKcyt_ERKcyt; kf_78*MEKcyt*ERKcyt - kb_78*MEKcyt_ERKcyt;
#   R79: ERKcyt + pMEKcyt => pMEKcyt_ERKcyt; kf_79*pMEKcyt*ERKcyt - kb_79*pMEKcyt_ERKcyt;
#   R80: ppMEKcyt + ERKcyt => ppMEKcyt_ERKcyt; kf_80*ppMEKcyt*ERKcyt - kb_80*ppMEKcyt_ERKcyt;
#   R81: MEKcyt + c_Raf_Ras_GTP => pMEKcyt + c_Raf_Ras_GTP; Vmax_81*c_Raf_Ras_GTP*MEKcyt/(Km_81 + MEKcyt);
#   R82: pMEKcyt + c_Raf_Ras_GTP => ppMEKcyt + c_Raf_Ras_GTP; Vmax_82*c_Raf_Ras_GTP*pMEKcyt/(Km_82 + pMEKcyt);
#   R83: MEKcyt_ERKcyt + c_Raf_Ras_GTP => pMEKcyt_ERKcyt + c_Raf_Ras_GTP; Vmax_83*c_Raf_Ras_GTP*MEKcyt_ERKcyt/(Km_83 + MEKcyt_ERKcyt);
#   R84: pMEKcyt_ERKcyt + c_Raf_Ras_GTP => ppMEKcyt_ERKcyt + c_Raf_Ras_GTP; Vmax_84*c_Raf_Ras_GTP*pMEKcyt_ERKcyt/(Km_84 + pMEKcyt_ERKcyt);
#   R85: MEKcyt + B_Raf_Ras_GTP => pMEKcyt + B_Raf_Ras_GTP; Vmax_85*B_Raf_Ras_GTP*MEKcyt/(Km_85 + MEKcyt);
#   R86: pMEKcyt + B_Raf_Ras_GTP => ppMEKcyt + B_Raf_Ras_GTP; Vmax_86*B_Raf_Ras_GTP*pMEKcyt/(Km_86 + pMEKcyt);
#   R87: MEKcyt_ERKcyt + B_Raf_Ras_GTP => pMEKcyt_ERKcyt + B_Raf_Ras_GTP; Vmax_87*B_Raf_Ras_GTP*MEKcyt_ERKcyt/(Km_87 + MEKcyt_ERKcyt);
#   R88: pMEKcyt_ERKcyt + B_Raf_Ras_GTP => ppMEKcyt_ERKcyt + B_Raf_Ras_GTP; Vmax_88*B_Raf_Ras_GTP*pMEKcyt_ERKcyt/(Km_88 + pMEKcyt_ERKcyt);
#   R89: MEKcyt + B_Raf_Rap1_GTP => pMEKcyt + B_Raf_Rap1_GTP; Vmax_89*B_Raf_Rap1_GTP*MEKcyt/(Km_89 + MEKcyt);
#   R90: pMEKcyt + B_Raf_Rap1_GTP => ppMEKcyt + B_Raf_Rap1_GTP; Vmax_90*B_Raf_Rap1_GTP*pMEKcyt/(Km_90 + pMEKcyt);
#   R91: MEKcyt_ERKcyt + B_Raf_Rap1_GTP => pMEKcyt_ERKcyt + B_Raf_Rap1_GTP; Vmax_91*B_Raf_Rap1_GTP*MEKcyt_ERKcyt/(Km_91 + MEKcyt_ERKcyt);
#   R92: pMEKcyt_ERKcyt + B_Raf_Rap1_GTP => ppMEKcyt_ERKcyt + B_Raf_Rap1_GTP; Vmax_92*B_Raf_Rap1_GTP*pMEKcyt_ERKcyt/(Km_92 + pMEKcyt_ERKcyt);
#   R93: pMEKcyt => MEKcyt; Vmax_93*PP2Acyt*pMEKcyt/(Km_93 + pMEKcyt);
#   R94: ppMEKcyt => pMEKcyt; Vmax_94*PP2Acyt*ppMEKcyt/(Km_94 + ppMEKcyt);
#   R95: pMEKcyt_ERKcyt => MEKcyt_ERKcyt; Vmax_95*PP2Acyt*pMEKcyt_ERKcyt/(Km_95 + pMEKcyt_ERKcyt);
#   R96: ppMEKcyt_ERKcyt => pMEKcyt_ERKcyt; Vmax_96*PP2Acyt*ppMEKcyt_ERKcyt/(Km_96 + ppMEKcyt_ERKcyt);
#   R97: ppERKcyt => ERKcyt; Vmax_97*MKP3cyt*ppERKcyt/(Km_97 + ppERKcyt);
#   R98: dppERKcyt => ppERKcyt + ERKcyt; Vmax_98*MKP3cyt*dppERKcyt/(Km_98 + dppERKcyt);
#   R99: ppMEKnuc_ERKnuc => ppMEKnuc + ppERKnuc; kf_99*ppMEKnuc_ERKnuc;
#   R100: 2ppERKnuc => dppERKnuc; kf_100*ppERKnuc*ppERKnuc - kb_100*dppERKnuc;
#   R101: MEKnuc + ERKnuc => MEKnuc_ERKnuc; kf_101*MEKnuc*ERKnuc - kb_101*MEKnuc_ERKnuc;
#   R102: ERKnuc + pMEKnuc => pMEKnuc_ERKnuc; kf_102*pMEKnuc*ERKnuc - kb_102*pMEKnuc_ERKnuc;
#   R103: ppMEKnuc + ERKnuc => ppMEKnuc_ERKnuc; kf_103*ppMEKnuc*ERKnuc - kb_103*ppMEKnuc_ERKnuc;
#   R104: pMEKnuc => MEKnuc; Vmax_104*PP2Anuc*pMEKnuc/(Km_104 + pMEKnuc);
#   R105: ppMEKnuc => pMEKnuc; Vmax_105*PP2Anuc*ppMEKnuc/(Km_105 + ppMEKnuc);
#   R106: pMEKnuc_ERKnuc => MEKnuc_ERKnuc; Vmax_106*PP2Anuc*pMEKnuc_ERKnuc/(Km_106 + pMEKnuc_ERKnuc);
#   R107: ppMEKnuc_ERKnuc => pMEKnuc_ERKnuc; Vmax_107*PP2Anuc*ppMEKnuc_ERKnuc/(Km_107 + ppMEKnuc_ERKnuc);
#   R108: ppERKnuc => ERKnuc; Vmax_108*MKP3nuc*ppERKnuc/(Km_108 + ppERKnuc);
#   R109: dppERKnuc => ppERKnuc + ERKnuc; Vmax_109*MKP3nuc*dppERKnuc/(Km_109 + dppERKnuc);
#   R110: pMEKcyt => ; kf_110*pMEKcyt;
#   R111: pMEKcyt => pMEKnuc + pMEKcyt; kf_111*pMEKcyt;
#   R112: pMEKnuc => pMEKcyt + pMEKnuc; kf_112*pMEKnuc;
#   R113: pMEKnuc => ; kf_113*pMEKnuc;
#   R114: MEKcyt_ERKcyt => ; kf_114*MEKcyt_ERKcyt;
#   R115: MEKcyt_ERKcyt => MEKnuc_ERKnuc + MEKcyt_ERKcyt; kf_115*MEKcyt_ERKcyt;
#   R116: MEKnuc_ERKnuc => MEKcyt_ERKcyt + MEKnuc_ERKnuc; kf_116*MEKnuc_ERKnuc;
#   R117: MEKnuc_ERKnuc => ; kf_117*MEKnuc_ERKnuc;
#   R118: ERKcyt => ; kf_118*ERKcyt;
#   R119: ERKcyt => ERKnuc + ERKcyt; kf_119*ERKcyt;
#   R120: ERKnuc => ERKcyt + ERKnuc; kf_120*ERKnuc;
#   R121: ERKnuc => ; kf_121*ERKnuc;
#   R122: MEKcyt => ; kf_122*MEKcyt;
#   R123: MEKcyt => MEKnuc + MEKcyt; kf_123*MEKcyt;
#   R124: MEKnuc => MEKcyt + MEKnuc; kf_124*MEKnuc;
#   R125: MEKnuc => ; kf_125*MEKnuc;
#   R126: ppERKcyt => ; kf_126*ppERKcyt;
#   R127: ppERKcyt => ppERKnuc + ppERKcyt; kf_127*ppERKcyt;
#   R128: ppERKnuc => ppERKcyt + ppERKnuc; kf_128*ppERKnuc;
#   R129: ppERKnuc => ; kf_129*ppERKnuc;
#   R130: ppMEKcyt => ; kf_130*ppMEKcyt;
#   R131: ppMEKcyt => ppMEKnuc + ppMEKcyt; kf_131*ppMEKcyt;
#   R132: ppMEKnuc => ppMEKcyt + ppMEKnuc; kf_132*ppMEKnuc;
#   R133: ppMEKnuc => ; kf_133*ppMEKnuc;
#   R134: ppMEKcyt_ERKcyt => ; kf_134*ppMEKcyt_ERKcyt;
#   mwc467edb6_a255_45d6_8014_33bd0209b36f: mwd4cc05d6_6e19_4e2e_b540_45954f2df4f0 + NGFR -> mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd; mwc467edb6_a255_45d6_8014_33bd0209b36f_mwd74ca4a6_566f_4161_859e_2b05bf2851fc*mwd4cc05d6_6e19_4e2e_b540_45954f2df4f0*NGFR - mwc467edb6_a255_45d6_8014_33bd0209b36f_mw924e0439_7ac5_4812_b1c2_11e46b4737b8*mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd;
#   mwe4f77287_e0fe_47f7_a74e_312151e578a4: mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd => mwb4295eb0_bd92_4221_b49d_bbbd48ca25bc; mwe4f77287_e0fe_47f7_a74e_312151e578a4_mwee585562_2580_4943_bd3e_731f12217004*mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd;
#   mw4f0ee780_12f5_436d_a227_c5e7cd420259: mwe009ad7f_90fd_4186_8855_77780724ddb8 => mwa4903466_fc58_4bfe_b3ec_76a90f9d20e2; mw4f0ee780_12f5_436d_a227_c5e7cd420259_mwfbeb575a_0864_4d0d_b862_240f7f6506c1*mwe009ad7f_90fd_4186_8855_77780724ddb8;
#
#   // Species initializations:
#   NGFR = 0.06189368;
#   NGFR has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   L_NGFR = 0;
#   L_NGFR has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pTrkA = 0;
#   pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pTrkA_endo = 0;
#   pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Shc_pTrkA = 0;
#   Shc_pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Shc_pTrkA_endo = 0;
#   Shc_pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pShc_pTrkA = 0;
#   pShc_pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pShc_pTrkA_endo = 0;
#   pShc_pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Grb2_SOS_pShc_pTrkA = 0;
#   Grb2_SOS_pShc_pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Grb2_SOS_pShc_pTrkA_endo = 0;
#   Grb2_SOS_pShc_pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   FRS2_pTrkA = 0;
#   FRS2_pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   FRS2_pTrkA_endo = 0;
#   FRS2_pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pFRS2_pTrkA = 0;
#   pFRS2_pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pFRS2_pTrkA_endo = 0;
#   pFRS2_pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Crk_C3G_pFRS2_pTrkA = 0;
#   Crk_C3G_pFRS2_pTrkA has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Crk_C3G_pFRS2_pTrkA_endo = 0;
#   Crk_C3G_pFRS2_pTrkA_endo has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Shc = 1;
#   Shc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Grb2_SOS_pShc = 0;
#   Grb2_SOS_pShc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   FRS2 = 1;
#   FRS2 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Crk_C3G = 0.4980158;
#   Crk_C3G has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Dok = 0.2993032;
#   Dok has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pDok = 0.000612296;
#   pDok has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Grb2 = 0.9373994;
#   Grb2 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   SOS = 0.03739938;
#   SOS has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Grb2_SOS = 0.06260062;
#   Grb2_SOS has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Ras_GTP = 0;
#   Ras_GTP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Ras_GDP = 0.1;
#   Ras_GDP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   B_Raf_Ras_GTP = 0;
#   B_Raf_Ras_GTP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   B_Raf = 0.2;
#   B_Raf has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   c_Raf = 0.5;
#   c_Raf has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Rap1_GTP = 0;
#   Rap1_GTP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ppMEKcyt_ERKcyt = 0;
#   ppMEKcyt_ERKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ppMEKcyt = 0;
#   ppMEKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ppERKcyt = 0;
#   ppERKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   dppERKcyt = 0;
#   dppERKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   MEKcyt = 0.1469897;
#   MEKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ERKcyt = 0.02803697;
#   ERKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   MEKcyt_ERKcyt = 0.1121076;
#   MEKcyt_ERKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pMEKcyt = 0;
#   pMEKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pMEKcyt_ERKcyt = 0;
#   pMEKcyt_ERKcyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ppMEKnuc_ERKnuc = 0;
#   ppMEKnuc_ERKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ppMEKnuc = 0;
#   ppMEKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ppERKnuc = 0;
#   ppERKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   dppERKnuc = 0;
#   dppERKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   MEKnuc = 1.941234;
#   MEKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   ERKnuc = 0.01599799;
#   ERKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   MEKnuc_ERKnuc = 0.8432791;
#   MEKnuc_ERKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pMEKnuc = 0;
#   pMEKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pMEKnuc_ERKnuc = 0;
#   pMEKnuc_ERKnuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   c_Raf_Ras_GTP = 0;
#   c_Raf_Ras_GTP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   B_Raf_Rap1_GTP = 0;
#   B_Raf_Rap1_GTP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Rap1_GDP = 0.2;
#   Rap1_GDP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Crk = 0.5019842;
#   Crk has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   C3G = 0.001984189;
#   C3G has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pDok_RasGAP = 8.45291e-05;
#   pDok_RasGAP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   RasGAP = 0.09991547;
#   RasGAP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   Grb2_pSOS = 0;
#   Grb2_pSOS has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pShc = 0;
#   pShc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pSOS = 0;
#   pSOS has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   pFRS2 = 0;
#   pFRS2 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwd4cc05d6_6e19_4e2e_b540_45954f2df4f0 = 0;
#   mwd4cc05d6_6e19_4e2e_b540_45954f2df4f0 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwf82ad06a_b8aa_40fa_a532_a1da44e3425f = 0.020631;
#   mwf82ad06a_b8aa_40fa_a532_a1da44e3425f has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwe009ad7f_90fd_4186_8855_77780724ddb8 = 0;
#   mwe009ad7f_90fd_4186_8855_77780724ddb8 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd = 0;
#   mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwb4295eb0_bd92_4221_b49d_bbbd48ca25bc = 0;
#   mwb4295eb0_bd92_4221_b49d_bbbd48ca25bc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwa4903466_fc58_4bfe_b3ec_76a90f9d20e2 = 0;
#   mwa4903466_fc58_4bfe_b3ec_76a90f9d20e2 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwe979ec8f_a55c_470c_a554_9fa8013eab74 = 5e-06;
#   mwe979ec8f_a55c_470c_a554_9fa8013eab74 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw4478fbeb_51b1_4764_92ad_a86d314ae0eb = 1;
#   mw4478fbeb_51b1_4764_92ad_a86d314ae0eb has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw29fa4e00_a430_4f11_b62e_1bcbc0a767a0 = 3e-05;
#   mw29fa4e00_a430_4f11_b62e_1bcbc0a767a0 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwa81400ac_76f5_4446_8a4d_6446ab4b11c9 = 0;
#   mwa81400ac_76f5_4446_8a4d_6446ab4b11c9 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw6782adfa_29ee_41a8_acbb_4c86c6c81596 = 0;
#   mw6782adfa_29ee_41a8_acbb_4c86c6c81596 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwe599c4c1_2d8e_446c_bf3f_4c97baced8a9 = 0;
#   mwe599c4c1_2d8e_446c_bf3f_4c97baced8a9 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw46e8693e_348e_4f1d_8c49_c13485fae7ba = 0;
#   mw46e8693e_348e_4f1d_8c49_c13485fae7ba has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mwe0b9d340_24f5_4c7e_a80f_4faadae6c0fc = 0;
#   mwe0b9d340_24f5_4c7e_a80f_4faadae6c0fc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw89ebbe2d_1ec2_457a_9367_6c5e86a1a924 = 0;
#   mw89ebbe2d_1ec2_457a_9367_6c5e86a1a924 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#   mw555a08dc_922d_4b35_8f69_5c6e8a4ad614 = 0;
#   mw555a08dc_922d_4b35_8f69_5c6e8a4ad614 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter;
#
#   // Compartment initializations:
#   mw3bc142df_1951_4fa9_b0a7_011c95012bbf = 0.001;
#   mw3bc142df_1951_4fa9_b0a7_011c95012bbf has MWBUILTINUNIT_liter;
#   mwc2fe3668_8fb0_4cfb_b795_99057e61e290 = 12;
#   mwc2fe3668_8fb0_4cfb_b795_99057e61e290 has MWBUILTINUNIT_liter;
#
#   // Variable initializations:
#   Km_104 = 15.657;
#   Km_104 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_105 = 15.657;
#   Km_105 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_106 = 15.657;
#   Km_106 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_107 = 15.657;
#   Km_107 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_108 = 0.02;
#   Km_108 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_109 = 0.02;
#   Km_109 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_39 = 0.1;
#   Km_39 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_40 = 0.1;
#   Km_40 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_41 = 0.1;
#   Km_41 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_42 = 0.1;
#   Km_42 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_43 = 0.1;
#   Km_43 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_44 = 0.1;
#   Km_44 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_45 = 0.1;
#   Km_45 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_58 = 0.02;
#   Km_58 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_59 = 25.641;
#   Km_59 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_60 = 25.641;
#   Km_60 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_61 = 25.641;
#   Km_61 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_62 = 1;
#   Km_62 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_63 = 1;
#   Km_63 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_64 = 1;
#   Km_64 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_70 = 0.01;
#   Km_70 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_71 = 1;
#   Km_71 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_72 = 1;
#   Km_72 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_81 = 0.16;
#   Km_81 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_82 = 0.16;
#   Km_82 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_83 = 0.16;
#   Km_83 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_84 = 0.16;
#   Km_84 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_85 = 0.16;
#   Km_85 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_86 = 0.16;
#   Km_86 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_87 = 0.16;
#   Km_87 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_88 = 0.16;
#   Km_88 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_89 = 0.16;
#   Km_89 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_90 = 0.16;
#   Km_90 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_91 = 0.16;
#   Km_91 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_92 = 0.16;
#   Km_92 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_93 = 15.657;
#   Km_93 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_94 = 15.657;
#   Km_94 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_95 = 15.657;
#   Km_95 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_96 = 15.657;
#   Km_96 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_97 = 0.02;
#   Km_97 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Km_98 = 0.02;
#   Km_98 has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   MKP3cyt = 0.018;
#   MKP3cyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   MKP3nuc = 0.006;
#   MKP3nuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   PP2Acyt = 0.24;
#   PP2Acyt has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   PP2Anuc = 0.08;
#   PP2Anuc has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Rap1GAP = 0.012;
#   Rap1GAP has MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity;
#   Vmax_104 = 180;
#   Vmax_104 has MWDERIVEDUNIT_1__minute;
#   Vmax_105 = 180;
#   Vmax_105 has MWDERIVEDUNIT_1__minute;
#   Vmax_106 = 180;
#   Vmax_106 has MWDERIVEDUNIT_1__minute;
#   Vmax_107 = 180;
#   Vmax_107 has MWDERIVEDUNIT_1__minute;
#   Vmax_108 = 3.6;
#   Vmax_108 has MWDERIVEDUNIT_1__minute;
#   Vmax_109 = 3.6;
#   Vmax_109 has MWDERIVEDUNIT_1__minute;
#   Vmax_39 = 1.2;
#   Vmax_39 has MWDERIVEDUNIT_1__minute;
#   Vmax_40 = 1.2;
#   Vmax_40 has MWDERIVEDUNIT_1__minute;
#   Vmax_41 = 1.2;
#   Vmax_41 has MWDERIVEDUNIT_1__minute;
#   Vmax_42 = 1.2;
#   Vmax_42 has MWDERIVEDUNIT_1__minute;
#   Vmax_43 = 1.2;
#   Vmax_43 has MWDERIVEDUNIT_1__minute;
#   Vmax_44 = 1.2;
#   Vmax_44 has MWDERIVEDUNIT_1__minute;
#   Vmax_45 = 1.2;
#   Vmax_45 has MWDERIVEDUNIT_1__minute;
#   Vmax_58 = 120;
#   Vmax_58 has MWDERIVEDUNIT_1__minute;
#   Vmax_59 = 60;
#   Vmax_59 has MWDERIVEDUNIT_1__minute;
#   Vmax_60 = 60;
#   Vmax_60 has MWDERIVEDUNIT_1__minute;
#   Vmax_61 = 60;
#   Vmax_61 has MWDERIVEDUNIT_1__minute;
#   Vmax_62 = 600;
#   Vmax_62 has MWDERIVEDUNIT_1__minute;
#   Vmax_63 = 600;
#   Vmax_63 has MWDERIVEDUNIT_1__minute;
#   Vmax_64 = 600;
#   Vmax_64 has MWDERIVEDUNIT_1__minute;
#   Vmax_70 = 2.88;
#   Vmax_70 has MWDERIVEDUNIT_1__minute;
#   Vmax_71 = 120;
#   Vmax_71 has MWDERIVEDUNIT_1__minute;
#   Vmax_72 = 120;
#   Vmax_72 has MWDERIVEDUNIT_1__minute;
#   Vmax_81 = 30;
#   Vmax_81 has MWDERIVEDUNIT_1__minute;
#   Vmax_82 = 30;
#   Vmax_82 has MWDERIVEDUNIT_1__minute;
#   Vmax_83 = 30;
#   Vmax_83 has MWDERIVEDUNIT_1__minute;
#   Vmax_84 = 30;
#   Vmax_84 has MWDERIVEDUNIT_1__minute;
#   Vmax_85 = 12;
#   Vmax_85 has MWDERIVEDUNIT_1__minute;
#   Vmax_86 = 12;
#   Vmax_86 has MWDERIVEDUNIT_1__minute;
#   Vmax_87 = 12;
#   Vmax_87 has MWDERIVEDUNIT_1__minute;
#   Vmax_88 = 12;
#   Vmax_88 has MWDERIVEDUNIT_1__minute;
#   Vmax_89 = 18;
#   Vmax_89 has MWDERIVEDUNIT_1__minute;
#   Vmax_90 = 18;
#   Vmax_90 has MWDERIVEDUNIT_1__minute;
#   Vmax_91 = 18;
#   Vmax_91 has MWDERIVEDUNIT_1__minute;
#   Vmax_92 = 18;
#   Vmax_92 has MWDERIVEDUNIT_1__minute;
#   Vmax_93 = 180;
#   Vmax_93 has MWDERIVEDUNIT_1__minute;
#   Vmax_94 = 180;
#   Vmax_94 has MWDERIVEDUNIT_1__minute;
#   Vmax_95 = 180;
#   Vmax_95 has MWDERIVEDUNIT_1__minute;
#   Vmax_96 = 180;
#   Vmax_96 has MWDERIVEDUNIT_1__minute;
#   Vmax_97 = 3.6;
#   Vmax_97 has MWDERIVEDUNIT_1__minute;
#   Vmax_98 = 3.6;
#   Vmax_98 has MWDERIVEDUNIT_1__minute;
#   kb_1 = 0.0166668;
#   kb_1 has MWDERIVEDUNIT_1__minute;
#   kb_100 = 4.5;
#   kb_100 has MWDERIVEDUNIT_1__minute;
#   kb_101 = 36;
#   kb_101 has MWDERIVEDUNIT_1__minute;
#   kb_102 = 36;
#   kb_102 has MWDERIVEDUNIT_1__minute;
#   kb_103 = 36;
#   kb_103 has MWDERIVEDUNIT_1__minute;
#   kb_18 = 12;
#   kb_18 has MWDERIVEDUNIT_1__minute;
#   kb_19 = 12;
#   kb_19 has MWDERIVEDUNIT_1__minute;
#   kb_20 = 12;
#   kb_20 has MWDERIVEDUNIT_1__minute;
#   kb_21 = 12;
#   kb_21 has MWDERIVEDUNIT_1__minute;
#   kb_22 = 12;
#   kb_22 has MWDERIVEDUNIT_1__minute;
#   kb_23 = 12;
#   kb_23 has MWDERIVEDUNIT_1__minute;
#   kb_24 = 6;
#   kb_24 has MWDERIVEDUNIT_1__minute;
#   kb_25 = 6;
#   kb_25 has MWDERIVEDUNIT_1__minute;
#   kb_26 = 6;
#   kb_26 has MWDERIVEDUNIT_1__minute;
#   kb_27 = 6;
#   kb_27 has MWDERIVEDUNIT_1__minute;
#   kb_46 = 1.008;
#   kb_46 has MWDERIVEDUNIT_1__minute;
#   kb_47 = 1.008;
#   kb_47 has MWDERIVEDUNIT_1__minute;
#   kb_48 = 12;
#   kb_48 has MWDERIVEDUNIT_1__minute;
#   kb_49 = 12;
#   kb_49 has MWDERIVEDUNIT_1__minute;
#   kb_50 = 12;
#   kb_50 has MWDERIVEDUNIT_1__minute;
#   kb_55 = 1.99999998;
#   kb_55 has MWDERIVEDUNIT_1__minute;
#   kb_56 = 0.0006;
#   kb_56 has MWDERIVEDUNIT_1__minute;
#   kb_65 = 0.12;
#   kb_65 has MWDERIVEDUNIT_1__minute;
#   kb_66 = 12;
#   kb_66 has MWDERIVEDUNIT_1__minute;
#   kb_67 = 12;
#   kb_67 has MWDERIVEDUNIT_1__minute;
#   kb_73 = 30;
#   kb_73 has MWDERIVEDUNIT_1__minute;
#   kb_74 = 30;
#   kb_74 has MWDERIVEDUNIT_1__minute;
#   kb_75 = 30;
#   kb_75 has MWDERIVEDUNIT_1__minute;
#   kb_77 = 4.5;
#   kb_77 has MWDERIVEDUNIT_1__minute;
#   kb_78 = 36;
#   kb_78 has MWDERIVEDUNIT_1__minute;
#   kb_79 = 36;
#   kb_79 has MWDERIVEDUNIT_1__minute;
#   kb_80 = 36;
#   kb_80 has MWDERIVEDUNIT_1__minute;
#   kf_1 = 0.049998;
#   kf_1 has MWDERIVEDUNIT_1__minute;
#   kf_10 = 0.0378;
#   kf_10 has MWDERIVEDUNIT_1__minute;
#   kf_100 = 600;
#   kf_100 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_101 = 978.24;
#   kf_101 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_102 = 978.24;
#   kf_102 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_103 = 978.24;
#   kf_103 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_11 = 0.0252;
#   kf_11 has MWDERIVEDUNIT_1__minute;
#   kf_110 = 6.48;
#   kf_110 has MWDERIVEDUNIT_1__minute;
#   kf_111 = 32.4;
#   kf_111 has MWDERIVEDUNIT_1__minute;
#   kf_112 = 0.48;
#   kf_112 has MWDERIVEDUNIT_1__minute;
#   kf_113 = 2.4;
#   kf_113 has MWDERIVEDUNIT_1__minute;
#   kf_114 = 3.12;
#   kf_114 has MWDERIVEDUNIT_1__minute;
#   kf_115 = 15.6;
#   kf_115 has MWDERIVEDUNIT_1__minute;
#   kf_116 = 0.42;
#   kf_116 has MWDERIVEDUNIT_1__minute;
#   kf_117 = 2.1;
#   kf_117 has MWDERIVEDUNIT_1__minute;
#   kf_118 = 0.216;
#   kf_118 has MWDERIVEDUNIT_1__minute;
#   kf_119 = 1.08;
#   kf_119 has MWDERIVEDUNIT_1__minute;
#   kf_12 = 0.0252;
#   kf_12 has MWDERIVEDUNIT_1__minute;
#   kf_120 = 0.1032;
#   kf_120 has MWDERIVEDUNIT_1__minute;
#   kf_121 = 0.516;
#   kf_121 has MWDERIVEDUNIT_1__minute;
#   kf_122 = 7.32;
#   kf_122 has MWDERIVEDUNIT_1__minute;
#   kf_123 = 36.6;
#   kf_123 has MWDERIVEDUNIT_1__minute;
#   kf_124 = 0.552;
#   kf_124 has MWDERIVEDUNIT_1__minute;
#   kf_125 = 2.76;
#   kf_125 has MWDERIVEDUNIT_1__minute;
#   kf_126 = 0.156;
#   kf_126 has MWDERIVEDUNIT_1__minute;
#   kf_127 = 0.78;
#   kf_127 has MWDERIVEDUNIT_1__minute;
#   kf_128 = 0.084;
#   kf_128 has MWDERIVEDUNIT_1__minute;
#   kf_129 = 0.42;
#   kf_129 has MWDERIVEDUNIT_1__minute;
#   kf_13 = 0.0252;
#   kf_13 has MWDERIVEDUNIT_1__minute;
#   kf_130 = 6.48;
#   kf_130 has MWDERIVEDUNIT_1__minute;
#   kf_131 = 32.4;
#   kf_131 has MWDERIVEDUNIT_1__minute;
#   kf_132 = 0.48;
#   kf_132 has MWDERIVEDUNIT_1__minute;
#   kf_133 = 2.4;
#   kf_133 has MWDERIVEDUNIT_1__minute;
#   kf_134 = 3.12;
#   kf_134 has MWDERIVEDUNIT_1__minute;
#   kf_135 = 15.6;
#   kf_135 has MWDERIVEDUNIT_1__minute;
#   kf_136 = 0.42;
#   kf_136 has MWDERIVEDUNIT_1__minute;
#   kf_137 = 2.1;
#   kf_137 has MWDERIVEDUNIT_1__minute;
#   kf_138 = 0.156;
#   kf_138 has MWDERIVEDUNIT_1__minute;
#   kf_139 = 0.78;
#   kf_139 has MWDERIVEDUNIT_1__minute;
#   kf_14 = 0.0252;
#   kf_14 has MWDERIVEDUNIT_1__minute;
#   kf_140 = 0.084;
#   kf_140 has MWDERIVEDUNIT_1__minute;
#   kf_141 = 0.42;
#   kf_141 has MWDERIVEDUNIT_1__minute;
#   kf_142 = 3.12;
#   kf_142 has MWDERIVEDUNIT_1__minute;
#   kf_143 = 15.6;
#   kf_143 has MWDERIVEDUNIT_1__minute;
#   kf_144 = 0.42;
#   kf_144 has MWDERIVEDUNIT_1__minute;
#   kf_145 = 2.1;
#   kf_145 has MWDERIVEDUNIT_1__minute;
#   kf_15 = 0.0252;
#   kf_15 has MWDERIVEDUNIT_1__minute;
#   kf_16 = 0.0252;
#   kf_16 has MWDERIVEDUNIT_1__minute;
#   kf_17 = 0.0252;
#   kf_17 has MWDERIVEDUNIT_1__minute;
#   kf_19 = 600;
#   kf_19 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_20 = 600;
#   kf_20 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_21 = 600;
#   kf_21 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_22 = 600;
#   kf_22 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_23 = 600;
#   kf_23 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_24 = 300;
#   kf_24 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_25 = 300;
#   kf_25 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_26 = 300;
#   kf_26 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_27 = 300;
#   kf_27 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_28 = 6;
#   kf_28 has MWDERIVEDUNIT_1__minute;
#   kf_29 = 6;
#   kf_29 has MWDERIVEDUNIT_1__minute;
#   kf_3 = 60;
#   kf_3 has MWDERIVEDUNIT_1__minute;
#   kf_30 = 120;
#   kf_30 has MWDERIVEDUNIT_1__minute;
#   kf_31 = 120;
#   kf_31 has MWDERIVEDUNIT_1__minute;
#   kf_32 = 0.132;
#   kf_32 has MWDERIVEDUNIT_1__minute;
#   kf_33 = 0.132;
#   kf_33 has MWDERIVEDUNIT_1__minute;
#   kf_34 = 0.132;
#   kf_34 has MWDERIVEDUNIT_1__minute;
#   kf_35 = 0.132;
#   kf_35 has MWDERIVEDUNIT_1__minute;
#   kf_36 = 0.132;
#   kf_36 has MWDERIVEDUNIT_1__minute;
#   kf_37 = 0.132;
#   kf_37 has MWDERIVEDUNIT_1__minute;
#   kf_38 = 0.132;
#   kf_38 has MWDERIVEDUNIT_1__minute;
#   kf_4 = 0.0378;
#   kf_4 has MWDERIVEDUNIT_1__minute;
#   kf_46 = 1.8;
#   kf_46 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_47 = 1.8;
#   kf_47 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_48 = 600;
#   kf_48 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_49 = 600;
#   kf_49 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_5 = 0.0378;
#   kf_5 has MWDERIVEDUNIT_1__minute;
#   kf_50 = 600;
#   kf_50 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_51 = 0.3;
#   kf_51 has MWDERIVEDUNIT_1__minute;
#   kf_52 = 0.3;
#   kf_52 has MWDERIVEDUNIT_1__minute;
#   kf_53 = 0.12;
#   kf_53 has MWDERIVEDUNIT_1__minute;
#   kf_54 = 0.12;
#   kf_54 has MWDERIVEDUNIT_1__minute;
#   kf_55 = 3;
#   kf_55 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_56 = 0.12;
#   kf_56 has MWDERIVEDUNIT_1__minute;
#   kf_57 = 0.0070002;
#   kf_57 has MWDERIVEDUNIT_1__minute;
#   kf_6 = 0.0378;
#   kf_6 has MWDERIVEDUNIT_1__minute;
#   kf_65 = 60;
#   kf_65 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_66 = 60;
#   kf_66 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_67 = 60;
#   kf_67 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_68 = 0.3;
#   kf_68 has MWDERIVEDUNIT_1__minute;
#   kf_69 = 0.006996;
#   kf_69 has MWDERIVEDUNIT_1__minute;
#   kf_7 = 0.0378;
#   kf_7 has MWDERIVEDUNIT_1__minute;
#   kf_73 = 3600;
#   kf_73 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_74 = 3600;
#   kf_74 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_75 = 3600;
#   kf_75 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_76 = 9;
#   kf_76 has MWDERIVEDUNIT_1__minute;
#   kf_77 = 600;
#   kf_77 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_78 = 978.24;
#   kf_78 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_79 = 978.24;
#   kf_79 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_8 = 0.0378;
#   kf_8 has MWDERIVEDUNIT_1__minute;
#   kf_80 = 978.24;
#   kf_80 has MWDERIVEDUNIT_1__micromolarity_minute;
#   kf_9 = 0.0378;
#   kf_9 has MWDERIVEDUNIT_1__minute;
#   kf_99 = 9;
#   kf_99 has MWDERIVEDUNIT_1__minute;
#   mwdfa3719d_20cc_4f14_b45e_3f097c3aff65 = 600;
#   mwdfa3719d_20cc_4f14_b45e_3f097c3aff65 has MWDERIVEDUNIT_1__micromolarity_minute;
#   mwe8ee00ff_3d59_44d5_8d7f_a2074823f29d_mw7d6fb5c7_061a_49ff_99a2_d76de2f025f7 = 3.849e-08;
#   const Km_87, Km_88, Km_89, Km_90, Km_91, Km_92, Km_93, Km_94, Km_95, Km_96;
#   const Km_97, Km_98, MKP3cyt, MKP3nuc, PP2Acyt, PP2Anuc, Rap1GAP, Vmax_104;
#   const Vmax_105, Vmax_106, Vmax_107, Vmax_108, Vmax_109, Vmax_39, Vmax_40;
#   const Vmax_41, Vmax_42, Vmax_43, Vmax_44, Vmax_45, Vmax_58, Vmax_59, Vmax_60;
#   const Vmax_61, Vmax_62, Vmax_63, Vmax_64, Vmax_70, Vmax_71, Vmax_72, Vmax_81;
#   const Vmax_82, Vmax_83, Vmax_84, Vmax_85, Vmax_86, Vmax_87, Vmax_88, Vmax_89;
#   const Vmax_90, Vmax_91, Vmax_92, Vmax_93, Vmax_94, Vmax_95, Vmax_96, Vmax_97;
#   const Vmax_98, kb_1, kb_100, kb_101, kb_102, kb_103, kb_18, kb_19, kb_20;
#   const kb_21, kb_22, kb_23, kb_24, kb_25, kb_26, kb_27, kb_46, kb_47, kb_48;
#   const kb_49, kb_50, kb_55, kb_56, kb_65, kb_66, kb_67, kb_73, kb_74, kb_75;
#   const kb_77, kb_78, kb_79, kb_80, kf_1, kf_10, kf_100, kf_101, kf_102, kf_103;
#   const kf_11, kf_110, kf_111, kf_112, kf_113, kf_114, kf_115, kf_116, kf_117;
#   const kf_118, kf_119, kf_12, kf_120, kf_121, kf_122, kf_123, kf_124, kf_125;
#   const kf_126, kf_127, kf_128, kf_129, kf_13, kf_130, kf_131, kf_132, kf_133;
#   const kf_134, kf_135, kf_136, kf_137, kf_138, kf_139, kf_14, kf_140, kf_141;
#   const kf_142, kf_143, kf_144, kf_145, kf_15, kf_16, kf_17, kf_19, kf_20;
#   const kf_21, kf_22, kf_23, kf_24, kf_25, kf_26, kf_27, kf_28, kf_29, kf_3;
#   const kf_30, kf_31, kf_32, kf_33, kf_34, kf_35, kf_36, kf_37, kf_38, kf_4;
#   const kf_46, kf_47, kf_48, kf_49, kf_5, kf_50, kf_51, kf_52, kf_53, kf_54;
#   const kf_55, kf_56, kf_57, kf_6, kf_65, kf_66, kf_67, kf_68, kf_69, kf_7;
#   const kf_73, kf_74, kf_75, kf_76, kf_77, kf_78, kf_79, kf_8, kf_80, kf_9;
#   const kf_99, mwdfa3719d_20cc_4f14_b45e_3f097c3aff65;
#
#   // Unit definitions:
#   unit MWBUILTINUNIT_liter = metre^3 * 0.001 dimensionless;
#   unit MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole = 1e-06 mole;
#   unit MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity = mole * 0.001 dimensionless / metre^3;
#   unit MWDERIVEDUNIT_1__minute = 0.0166667 dimensionless / second;
#   unit MWDERIVEDUNIT_1__micromolarity_minute = metre^3 * 16.6667 dimensionless / (mole * second);
#   unit MWDERIVEDUNIT_1__molarity_second = metre^3 * 0.001 dimensionless / (mole * second);
#   unit MWDERIVEDUNIT_1__second = dimensionless / second;
#   unit MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole_per_MWBUILTINUNIT_liter = 1e-06 mole / (metre^3 * 0.001 dimensionless);
#
#   // Display Names:
#   MWBUILTINUNIT_liter is "liter";
#   MWBUILTINPREFIX_micro_MWBUILTINUNIT_mole is "micromole";
#   MWBUILTINPREFIX_micro_MWBUILTINUNIT_molarity is "micromolarity";
#   MWDERIVEDUNIT_1__minute is "1/minute";
#   MWDERIVEDUNIT_1__micromolarity_minute is "1/(micromolarity*minute)";
#   MWDERIVEDUNIT_1__molarity_second is "1/(molarity*second)";
#   MWDERIVEDUNIT_1__second is "1/second";
#   mw3bc142df_1951_4fa9_b0a7_011c95012bbf is "Neuron";
#   mwc2fe3668_8fb0_4cfb_b795_99057e61e290 is "Interstitial fluid";
#   mwd4cc05d6_6e19_4e2e_b540_45954f2df4f0 is "trkaI_int";
#   mwf82ad06a_b8aa_40fa_a532_a1da44e3425f is "pro_TrkA";
#   mwe009ad7f_90fd_4186_8855_77780724ddb8 is "L_NGFR_I";
#   mw5afa8250_0cf0_40a2_a97a_f7cf20a9cfbd is "NGFR_I";
#   mwb4295eb0_bd92_4221_b49d_bbbd48ca25bc is "NGFR_I_deg";
#   mwa4903466_fc58_4bfe_b3ec_76a90f9d20e2 is "L_NGFR_I_deg";
#   mwe979ec8f_a55c_470c_a554_9fa8013eab74 is "NGFR_interstitial_fluid";
#   mw4478fbeb_51b1_4764_92ad_a86d314ae0eb is "source";
#   mw29fa4e00_a430_4f11_b62e_1bcbc0a767a0 is "NGF";
#   mwa81400ac_76f5_4446_8a4d_6446ab4b11c9 is "NGFdeg";
#   mw6782adfa_29ee_41a8_acbb_4c86c6c81596 is "NGFR_L_interstitial_fluid";
#   mwe599c4c1_2d8e_446c_bf3f_4c97baced8a9 is "tanezumab";
#   mw46e8693e_348e_4f1d_8c49_c13485fae7ba is "NGF_tanezumab";
#   mwe0b9d340_24f5_4c7e_a80f_4faadae6c0fc is "tz_deg";
#   mw89ebbe2d_1ec2_457a_9367_6c5e86a1a924 is "trkaI";
#   mw555a08dc_922d_4b35_8f69_5c6e8a4ad614 is "trkaI_deg";
#   mwdfa3719d_20cc_4f14_b45e_3f097c3aff65 is "kf_18";
#   mwe8ee00ff_3d59_44d5_8d7f_a2074823f29d is "reaction_1";
#   mw711542fd_b235_40f7_9782_f78eb654d773 is "reaction_2";
#   mwc7ff2b7b_e2c9_4420_87bc_f285d98de30b is "reaction_3";
#   mw02775189_5c04_4c2f_a5f4_2f15723e1ece is "reaction_4";
#   mwfb02ea2a_1f06_4f8f_80a0_721149f213ff is "reaction_5";
#   mw12b652db_d0da_4723_b160_001fa36f9190 is "reaction_6";
#   mwffc6fab3_9f90_4da4_bf71_214b9b723899 is "reaction_7";
#   mwf371eb20_7bda_4140_9a43_dfad70900057 is "reaction_8";
#   mw8105f0dc_19ad_4f7a_80df_3f84de216c42 is "Intercomp mass transfer";
#   mw9da48a51_bbd0_4395_9883_8441d8153b00 is "reaction_9";
#   mwc467edb6_a255_45d6_8014_33bd0209b36f is "reaction_10";
#   mwe4f77287_e0fe_47f7_a74e_312151e578a4 is "reaction_14";
#   mw4f0ee780_12f5_436d_a227_c5e7cd420259 is "reaction_15";
# end
